# %%
import matplotlib.pyplot as plt
import nivapy3 as nivapy
import pandas as pd

# %%
# List all available parameters
par_df = nivapy.da.get_nve_hydapi_parameters()
par_df
# Out:
#     parameter                            parameterName  \
# 0           0                                   Nedbør
# 1        1000                                Vannstand
# 2        1001                               Vannføring
# 3        1002                            Vannhastighet
# 4        1003                           Vanntemperatur
# 5        1004                             Magasinvolum
# 6        1006                             Ledningsevne
# 7        1012                  Overvannstand kraftverk
# 8        1200  Konsentrasjon suspendert min. materiale
# 9        1208         Konsentrasjon organisk materiale
# 10       1215               Turbiditet (Nepheometrisk)
# 11         14                              Vindretning
# 12         15                            Vindhastighet
# 13         17                           Lufttemperatur
# 14          2                    Relativ luftfuktighet
# 15       2000                           Grunnvannsnivå
# 16       2001                            Markfuktighet
# 17       2002                                 Snødybde
# 18       2003                    Snøens vannekvivalent
# 19       2005                                Poretrykk
# 20       2006                           Jordtemperatur
# 21       2015                      Grunnvanntemperatur
# 22       2040                      Overflatetemperatur
# 23       4050                                     Vekt
# 24       5130        Grunnvannsnivå - dyp under bakken
# 25          8                      Kortbølget stråling
# 26       8291                           Ammon Nitrogen
# 27       8292                          Nitrat Nitrogen
# 28          9                      Langbølget stråling
# 29       9100                 Spenning, solstrømanlegg
# 30       9103      Spenning, batterilader på faststrøm
# 31       9104                       Sekundær vannstand
# 32       9109                  Sekundær vanntemperatur
# 33       9153                       Generell parameter
# 34       9155                     Instrumenttemperatur
# 35       9156                                    Volum
# 36       9301                            Nedbør rådata
#
#                            parameterNameEng          unit
# 0                             Precipitation            mm
# 1                                     Stage             m
# 2                                 Discharge          m³/s
# 3                               Water speed           m/s
# 4                         Water temperature            °C
# 5                          Reservoir volume  millioner m³
# 6                              Conductivity         µS/cm
# 7                Head water level-hydropow.             m
# 8   Concentration suspended (inorg.) sedim.          mg/l
# 9         Concentration of organic material          mg/l
# 10                Turbidity (Nephelometric)           NTU
# 11                           Wind direction             °
# 12                               Wind speed           m/s
# 13                          Air temperature            °C
# 14                        Relative humidity             %
# 15                        Groundwater level             m
# 16                               Soil water             %
# 17                               Snow depth            cm
# 18                 Water equivalent of snow             m
# 19                            Pore pressure            Pa
# 20                         Soil temperature            °C
# 21                 Ground water temperature            °C
# 22                      Surface temperature            °C
# 23                                   Weight            kg
# 24                        Groundwater level             m
# 25                     Short wave radiation          W/m²
# 26                        Ammonium Nitrogen          µg/l
# 27                         Nitrate Nitrogen          µg/l
# 28                      Long wave radiation          W/m²
# 29             Voltage, solar power battery          Volt
# 30   Voltage, Mains powered battery charger          Volt
# 31                     Secundary waterlevel             m
# 32              Secondary water temperature            °C
# 33                        Generic parameter             #
# 34                   Instrument temperature            °C
# 35                                   Volume         liter
# 36                           Precip rawdata            mm

# %%
# List all stations
stn_df = nivapy.da.get_nve_hydapi_stations()
print(len(stn_df), "stations available.")
stn_df.head()
# Out:
# 1784 stations available.
#   station_id     station_name  latitude  longitude  utmEast_Z33  utmNorth_Z33  \
# 0     1.15.0           Femsjø  59.13015   11.48516       298887       6559841
# 1    1.198.0             Berg  59.92993   11.40768       299271       6649056
# 2    1.200.0          Lierelv  59.92038   11.53180       306146       6647624
# 3     1.40.0  Unnebergsbekken  11.14828    5.55338      -535845       1248998
# 4     1.41.0        Lognselva  11.14828    5.55338      -535845       1248998
#
#    masl         riverName councilNumber     councilName  ...    culQ5  \
# 0    81  Haldenvassdraget          3001          Halden  ...      NaN
# 1   177         Riserelva          3026  Aurskog-Høland  ...      NaN
# 2   134  Haldenvassdraget          3026  Aurskog-Høland  ...  35.3131
# 3     0                                                  ...      NaN
# 4     0                                                  ...      NaN
#
#     culQ10   culQ20   culQ50    culHm    culH5   culH10   culH20   culH50  \
# 0      NaN      NaN      NaN  79.5551  79.6937  79.8507  80.0226  80.2810
# 1      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2  36.5231  37.1222  37.4959   2.2503   2.3432   2.3588   2.3664   2.3711
# 3      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 4      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#                                           seriesList
# 0  [{'parameterName': 'Vannstand', 'parameter': 1...
# 1  [{'parameterName': 'Vannstand', 'parameter': 1...
# 2  [{'parameterName': 'Vannstand', 'parameter': 1...
# 3  [{'parameterName': 'Vannstand', 'parameter': 1...
# 4  [{'parameterName': 'Vannstand', 'parameter': 1...
#
# [5 rows x 98 columns]

# %%
# Map all stations
nivapy.spatial.quickmap(
    stn_df, cluster=True, kartverket=True, aerial_imagery=True, popup="station_id"
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_90a47e7c5ba2488dba355830a16836fd%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css%22/%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_90a47e7c5ba2488dba355830a16836fd%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3 ...

# %%
# Paths to files and folders

# This set of stations doesn't include previous versions of some of the stations,
# that have been discontinued (e.g. at Cægarrasjohka), therefore needs revisiting
nve_site_ids_fpath = r"../data/Subcatchment_outlets.xlsx"
station_ids = pd.read_excel(
    nve_site_ids_fpath, sheet_name="NVE_datadownload_01-2022", index_col=0
)
station_ids.index
# Out:
# Index(['234.13.0', '234.14.0', '234.5.0', '234.2.0', '234.4.0', '234.10.0',
#        '234.16.0', '234.18.0', '234.1.0'],
#       dtype='object', name='stasjonID')

# %%
station_ids.index[0:2]
# Out:
# Index(['234.13.0', '234.14.0'], dtype='object', name='stasjonID')

# %%
# Define stations, parameters and time period of interest
stn_ids = station_ids.index
par_ids = [1001]
st_dt = "1900-01-01"
end_dt = "2022-01-01"

# Query
df = nivapy.da.query_nve_hydapi(stn_ids, par_ids, st_dt, end_dt, resolution=1440)
df
# Out:
#        station_id station_name parameter parameter_name parameter_name_eng  \
# 0         234.1.0       Polmak      1001     Vannføring          Discharge
# 1         234.1.0       Polmak      1001     Vannføring          Discharge
# 2         234.1.0       Polmak      1001     Vannføring          Discharge
# 3         234.1.0       Polmak      1001     Vannføring          Discharge
# 4         234.1.0       Polmak      1001     Vannføring          Discharge
# ...           ...          ...       ...            ...                ...
# 112900    234.2.0    Jiesjokka      1001     Vannføring          Discharge
# 112901    234.2.0    Jiesjokka      1001     Vannføring          Discharge
# 112902    234.2.0    Jiesjokka      1001     Vannføring          Discharge
# 112903    234.2.0    Jiesjokka      1001     Vannføring          Discharge
# 112904    234.2.0    Jiesjokka      1001     Vannføring          Discharge
#
#        method                  datetime      value  unit  correction  quality
# 0        Mean 1911-07-24 11:00:00+00:00  253.30380  m³/s           0        3
# 1        Mean 1911-07-25 11:00:00+00:00  241.09810  m³/s           0        3
# 2        Mean 1911-07-26 11:00:00+00:00  235.14230  m³/s           0        3
# 3        Mean 1911-07-27 11:00:00+00:00  232.20080  m³/s           0        3
# 4        Mean 1911-07-28 11:00:00+00:00  238.10800  m³/s           0        3
# ...       ...                       ...        ...   ...         ...      ...
# 112900   Mean 1982-07-22 11:00:00+00:00        NaN  m³/s           0        2
# 112901   Mean 1982-07-23 11:00:00+00:00   13.88442  m³/s           0        2
# 112902   Mean 1982-07-24 11:00:00+00:00        NaN  m³/s           0        2
# 112903   Mean 1982-07-25 11:00:00+00:00        NaN  m³/s           0        2
# 112904   Mean 1982-07-26 11:00:00+00:00   13.23501  m³/s           0        2
#
# [112905 rows x 11 columns]

# %% [markdown]
# See here for an interpretation of the correction and quality integer values: https://hydapi.nve.no/UserDocumentation/
#
# Quality types:
# Unknown = 0
# Uncontrolled = 1
# PrimaryControlled = 2
# SecondaryControlled = 3
#
# Correction type indicates whether the value has been corrected. e.g.:
# 0: No changes
# 1: Manual- or ice correction
# 2: Interpolation
# 3: Value computed with models or/and other series
# 4: Daily mean computed with arithmetic mean. (Only used on series where we normally should use discharge curve)
# 13: The value is calculated based on a similar station or a station close by
# 14: The value is missing, and is only calculated based on statistical information for the data series

# %%
# Unstack
df2 = df[["datetime", "value", "station_name"]]
df2.set_index(["datetime", "station_name"], inplace=True)
df2 = df2.unstack("station_name")

# Plot
df2.plot(subplots=True, sharex=True, figsize=(12, 12))
plt.tight_layout()

# %%
df2.head()
# Out:
#                                   value                                \
# station_name              Cærrogæsjokka Jiesjokka Julelv Njalmigoaika
# datetime
# 1911-07-24 11:00:00+00:00           NaN       NaN    NaN          NaN
# 1911-07-25 11:00:00+00:00           NaN       NaN    NaN          NaN
# 1911-07-26 11:00:00+00:00           NaN       NaN    NaN          NaN
# 1911-07-27 11:00:00+00:00           NaN       NaN    NaN          NaN
# 1911-07-28 11:00:00+00:00           NaN       NaN    NaN          NaN
#
#
# station_name                 Polmak Polmak nye Smalfjord Veahkkava, Iesjokka
# datetime
# 1911-07-24 11:00:00+00:00  253.3038        NaN       NaN                 NaN
# 1911-07-25 11:00:00+00:00  241.0981        NaN       NaN                 NaN
# 1911-07-26 11:00:00+00:00  235.1423        NaN       NaN                 NaN
# 1911-07-27 11:00:00+00:00  232.2008        NaN       NaN                 NaN
# 1911-07-28 11:00:00+00:00  238.1080        NaN       NaN                 NaN

# %%
df_stacked_fpath = r'../data/NVE/NVE_Q_download_2022-01-20_allinfo_stacked.csv'
df_unstacked_fpath = r'../data/NVE/NVE_Q_download_2022-01-20_unstacked.csv'

df.to_csv(df_stacked_fpath, index=False)
df2.to_csv(df_unstacked_fpath)
